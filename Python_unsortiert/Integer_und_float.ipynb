# %% [markdown]
# [Zurück zum Inhaltsverzeichnis](_Inhaltsverzeichnis_.ipynb)

# %% [markdown]
# ## Integer / Float

# %% [markdown]
# Integer nennt man in Python `int`.
#
# Kommazahlen, werde im Englischen Floating-POINT-Zahlen genannt , und in Python `float`
#
# In Python gibt es nur einen Datentyp für Integer (in Java bspw. gibt es byte, short, int, long und char)
# und dieser Datentyp kann **beliebig** große Zahlen speichern.
#
# In Java ist die größte speicherbare Ganzzahl das long und hier ist das Maximum 2\**63-1

# %%
groesste_java_ganzzahl = 2**63-1

# %%
groesste_java_ganzzahl
# Out:
# 9223372036854775807

# %%
f"{groesste_java_ganzzahl:_}"
# Out:
# '9_223_372_036_854_775_807'

# %%
nicht_mal_ansatzweise_die_groesste_ganzzahl_in_python = 91462491234669371469345628945656248956948756249567295762349546578962345764389256782346523495347572346589746235723468956234785642378956478923658934652347895624589243657893465436502346523465234656723457284052348524245

# %%
print(nicht_mal_ansatzweise_die_groesste_ganzzahl_in_python**10)
# Out:
# ...

# %%
type(...)
# Out:
# int

# %% [markdown]
# Bei Gleitkommazahlen aka Floating-point-number, gibt es in Java bspw. zwei float und double (double weil doppelt so "präzise"/lang)
#
# In Python gibt es für Gleitkommazahlen kein double sondern nur float

# %%
12.341212**30
# Out:
# 5.5047092282973795e+32

# %%
5.5*(10**32)
