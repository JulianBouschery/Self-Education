# %% [markdown]
# # PCED Block 4: Data Analysis and Modeling
#
# ## Objectives covered by the block:
# - **Data Analysis with Pandas and NumPy**
# - **Statistical Methods and Machine Learning**
#
# ### Objective 4.1.1 – Manage data effectively with Pandas
#
# 1. **Explain how you would handle missing values in a DataFrame using Pandas. Provide examples of filling, dropping, and interpolating missing values.**
#
# 2. **What are the key differences between filtering and sorting data in Pandas? Provide code examples for both.**
#
# 3. **Explain how you would merge or join two DataFrames. What are the different types of joins in Pandas?**
#
# ---
#
# ### Objective 4.1.2 – Understand and Utilize the Relationship Between DataFrame and Series in Pandas
#
# 4. **What are the main conceptual differences between a Pandas DataFrame and a Pandas Series? Provide examples of use cases for each.**
#
# 5. **Explain how you would use the `.iloc` and `.loc` methods to select specific data in a DataFrame. Provide code examples to demonstrate the difference between the two.**
#
# 6. **Discuss the advantages of using vectorized operations in Pandas for data manipulation compared to traditional Python loops.**
#
# ---
#
# ### Objective 4.1.3 – Perform Array Operations and Differentiate Data Structures with NumPy
#
# 7. **Describe the key differences between a Python list, a NumPy array, and a Pandas Series. How do their performance characteristics differ?**
#
# 8. **What is broadcasting in NumPy, and how does it enable efficient computation? Provide an example where broadcasting can be applied.**
#
# 9. **Compare and contrast the use of NumPy arrays versus Pandas DataFrames for data analysis tasks. When would you choose one over the other?**
#
# ---
#
# ### Objective 4.1.4 – Apply and Analyze Data Organization Techniques in Pandas and NumPy
#
# 10. **Explain the purpose of the `.groupby()` method in Pandas. How would you use this method to compute summary statistics for different groups in a dataset?**
#
# 11. **What is the difference between a pivot table and a cross table in Pandas? Provide examples of when each would be useful.**
#
# 12. **Demonstrate how to compute descriptive statistics (mean, median, standard deviation) using both Pandas and NumPy. Provide code examples.**
#
# ---
#
# ### Objective 4.2.1 – Apply Python's descriptive statistics for dataset analysis
#
# 13. **Explain the differences between mean, median, and mode. Why is it important to calculate all three when analyzing a dataset?**
#
# 14. **How would you calculate the variance and standard deviation of a dataset using Python? Provide code examples.**
#
# 15. **Discuss the importance of understanding variance when working with machine learning models. How can variance in a dataset impact model performance?**
#
# ---
#
# ### Objective 4.2.2 – Recognize the importance of test datasets in model evaluation
#
# 16. **Why is it important to use a test dataset when training machine learning models? What could happen if you evaluate your model on the training data?**
#
# 17. **Describe the difference between training, validation, and test datasets. What role does each one play in model evaluation and tuning?**
#
# 18. **How would you ensure that your test dataset is representative of the real-world data your model will encounter?**
#
# ---
#
# ### Objective 4.2.3 – Analyze and Evaluate Supervised Learning Algorithms and Model Accuracy
#
# 19. **Explain the bias-variance tradeoff in machine learning. How does it relate to underfitting and overfitting?**
#
# 20. **What is the primary difference between linear regression and logistic regression? When would you use one over the other?**
#
# 21. **Describe how overfitting can occur when training a supervised learning model. What are some techniques to prevent overfitting?**
#
# 22. **How would you evaluate the accuracy of a machine learning model? Discuss the difference between using accuracy, precision, recall, and F1-score as evaluation metrics.**
